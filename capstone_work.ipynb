# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
data_set = pd.read_csv('file.csv')

# %%
data_set.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data_set[data_set['year']==2009]
# Out:
#       year   price
# 12    2009   58.00
# 13    2009   56.25
# 14    2009   57.75
# 15    2009   59.50
# 16    2009   71.20
# ...    ...     ...
# 8021  2009   84.00
# 8022  2009  100.00
# 8023  2009  115.00
# 8024  2009  100.00
# 8025  2009  100.00
#
# [870 rows x 2 columns]

# %%
X = data_set[['year','commodity']]
y = data_set['price']

# %%
plt.figure(figsize=(30,40))
plt.plot(data_set['year'],data_set['price'],'o',)
plt.show()

# %%
year_2008 = data_set[data_set['year'] == 2008]

# %%
year_2009 = data_set[data_set['year']==2009]

# %%
year_2010 =  data_set[data_set['year']==2010]
yea_2011 = data_set[data_set['year']==2011]
year_2012 = data_set[data_set['year']==2012]
year_2013 = data_set[data_set['year']==2013]
year_2014 = data_set[data_set['year']==2014]
year_2015 = data_set[data_set['year']==2015]
year_2016 = data_set[data_set['year']==2016]
year_2017 = data_set[data_set['year']==2017]

# %%
year_2017['price']
# Out:
# 102     120.0
# 103     140.0
# 104     140.0
# 105     150.0
# 106     150.0
#         ...
# 8107    350.0
# 8108    480.0
# 8109    593.0
# 8110    650.0
# 8111    650.0
# Name: price, Length: 408, dtype: float64

# %%
data_set.describe()
# Out:
#               year        price
# count  8112.000000  8112.000000
# mean   2012.325197   105.432938
# std       2.720356   117.479997
# min    2008.000000     0.870000
# 25%    2010.000000    26.250000
# 50%    2012.000000    66.250000
# 75%    2015.000000   144.000000
# max    2017.000000  1000.000000

# %%
data_set[data_set['year'] == 2008].mean()
# Out:
# year     2008.000000
# price      46.053275
# dtype: float64

# %%
date_set_work = data_set['price'] + data_set['year']

# %%
date_set_work
# Out:
# 0       2038.75
# 1       2042.25
# 2       2049.67
# 3       2054.50
# 4       2060.00
#          ...
# 8107    2367.00
# 8108    2497.00
# 8109    2610.00
# 8110    2667.00
# 8111    2667.00
# Length: 8112, dtype: float64

# %%
plt.plot(yea_2011['year'],yea_2011['price'])
