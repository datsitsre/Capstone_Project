# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv('wfp_market_food_prices.csv')

# %%
df
# Out:
#         adm0_id    adm0_name  adm1_id          adm1_name  mkt_id  mkt_name  \
# 0             1  Afghanistan      272         Badakhshan     266  Fayzabad
# 1             1  Afghanistan      272         Badakhshan     266  Fayzabad
# 2             1  Afghanistan      272         Badakhshan     266  Fayzabad
# 3             1  Afghanistan      272         Badakhshan     266  Fayzabad
# 4             1  Afghanistan      272         Badakhshan     266  Fayzabad
# ...         ...          ...      ...                ...     ...       ...
# 743909    70001  South Sudan     2750  Eastern Equatoria    1786     Torit
# 743910    70001  South Sudan     2750  Eastern Equatoria    1786     Torit
# 743911    70001  South Sudan     2750  Eastern Equatoria    1786     Torit
# 743912    70001  South Sudan     2750  Eastern Equatoria    1786     Torit
# 743913    70001  South Sudan     2750  Eastern Equatoria    1786     Torit
#
# ...

# %%
data_set = df.loc[df['adm0_name'] == 'Ghana']

# %%
data_set
# Out:
#         adm0_id adm0_name  adm1_id      adm1_name  mkt_id mkt_name  cm_id  \
# 135405       94     Ghana     1328  Greater Accra     209    Accra     51
# 135406       94     Ghana     1328  Greater Accra     209    Accra     51
# 135407       94     Ghana     1328  Greater Accra     209    Accra     51
# 135408       94     Ghana     1328  Greater Accra     209    Accra     51
# 135409       94     Ghana     1328  Greater Accra     209    Accra     51
# ...         ...       ...      ...            ...     ...      ...    ...
# 143512       94     Ghana     1324        Ashanti     223    Ejura     99
# 143513       94     Ghana     1324        Ashanti     223    Ejura     99
# 143514       94     Ghana     1324        Ashanti     223    Ejura     99
# 143515       94     Ghana     1324        Ashanti     223    Ejura     99
# 143516       94     Ghana     1324        Ashanti     223    Ejura     99
#
#        cm_name  cur_id cur_name  pt_id    pt_name  um_id     um_name  \
# ...

# %%
data_set.to_csv('market_prices.csv')

# %%
pwd
# Out:
# '/home/james/Digicap/capstone'

# %%
data_set
# Out:
#         adm0_id adm0_name  adm1_id      adm1_name  mkt_id mkt_name  cm_id  \
# 135405       94     Ghana     1328  Greater Accra     209    Accra     51
# 135406       94     Ghana     1328  Greater Accra     209    Accra     51
# 135407       94     Ghana     1328  Greater Accra     209    Accra     51
# 135408       94     Ghana     1328  Greater Accra     209    Accra     51
# 135409       94     Ghana     1328  Greater Accra     209    Accra     51
# ...         ...       ...      ...            ...     ...      ...    ...
# 143512       94     Ghana     1324        Ashanti     223    Ejura     99
# 143513       94     Ghana     1324        Ashanti     223    Ejura     99
# 143514       94     Ghana     1324        Ashanti     223    Ejura     99
# 143515       94     Ghana     1324        Ashanti     223    Ejura     99
# 143516       94     Ghana     1324        Ashanti     223    Ejura     99
#
#        cm_name  cur_id cur_name  pt_id    pt_name  um_id     um_name  \
# ...

# %%
data_remove = data_set.drop(columns=['mkt_id','adm0_id','adm1_id','adm0_name','cm_id','cur_id','pt_id','um_id','mp_commoditysource'],axis=1)

# %%
data_remove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8112 entries, 135405 to 143516
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   adm1_name  8112 non-null   object
#  1   mkt_name   8112 non-null   object
#  2   cm_name    8112 non-null   object
#  3   cur_name   8112 non-null   object
#  4   pt_name    8112 non-null   object
#  5   um_name    8112 non-null   object
#  6   mp_month   8112 non-null   int64
#  7   mp_year    8112 non-null   int64
#  8   mp_price   8112 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 891.8+ KB

# %%
data_remove.adm1_name.unique()
# Out:
# array(['Greater Accra', 'Western', 'Eastern', 'Central', 'Ashanti',
#        'Brong Ahafo', 'Volta', 'Northern', 'Upper East', 'Upper West'],
#       dtype=object)

# %%
data_remove
# Out:
#             adm1_name mkt_name cm_name cur_name    pt_name     um_name  \
# 135405  Greater Accra    Accra   Maize      GHS  Wholesale      100 KG
# 135406  Greater Accra    Accra   Maize      GHS  Wholesale      100 KG
# 135407  Greater Accra    Accra   Maize      GHS  Wholesale      100 KG
# 135408  Greater Accra    Accra   Maize      GHS  Wholesale      100 KG
# 135409  Greater Accra    Accra   Maize      GHS  Wholesale      100 KG
# ...               ...      ...     ...      ...        ...         ...
# 143512        Ashanti    Ejura     Yam      GHS  Wholesale  100 Tubers
# 143513        Ashanti    Ejura     Yam      GHS  Wholesale  100 Tubers
# 143514        Ashanti    Ejura     Yam      GHS  Wholesale  100 Tubers
# 143515        Ashanti    Ejura     Yam      GHS  Wholesale  100 Tubers
# 143516        Ashanti    Ejura     Yam      GHS  Wholesale  100 Tubers
#
#         mp_month  mp_year  mp_price
# 135405         1     2008     30.75
# 135406         2     2008     34.25
# ...

# %%
sns.scatterplot(data=data_remove,x='cm_name',y='mp_year')
# Out:
# <AxesSubplot:xlabel='cm_name', ylabel='mp_year'>

# %%
sns.scatterplot(data=data_remove,x='mp_year',y='cm_name')
# Out:
# <AxesSubplot:xlabel='mp_year', ylabel='cm_name'>

# %%
sns.scatterplot(data=data_remove,x='cm_name',y='mp_price')
# Out:
# <AxesSubplot:xlabel='cm_name', ylabel='mp_price'>

# %%
sns.scatterplot(data=data_remove,x='mp_price',y='mp_year')
# Out:
# <AxesSubplot:xlabel='mp_price', ylabel='mp_year'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x = data_remove.loc[0:1,5:6]
# Out:
# -----------------------------------------------------
# TypeError           Traceback (most recent call last)
# <ipython-input-81-bf017866adda> in <module>
# ----> 1 x = data_remove.loc[0:1,5:6]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %%
data = LinearRegression()

# %%
x_test,x_train, y_test,y_train = train_test_split(data_remove['cm_name'],data_remove[',mp_year'],random_state=0.4,)
# Out:
# -----------------------------------------------------
# KeyError            Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ',mp_year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError            Traceback (most recent call last)
# <ipython-input-82-e7aea6749146> in <module>
# ...

# %%
dat = LinearRegression(fjfj)
# Out:
# -----------------------------------------------------
# NameError           Traceback (most recent call last)
# <ipython-input-83-828d4a48a7ff> in <module>
# ----> 1 dat = LinearRegression(fjfj)
#
# NameError: name 'fjfj' is not defined

# %%
data_remove.
